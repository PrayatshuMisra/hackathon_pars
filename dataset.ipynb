# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\codes\Datasets\patients_data_scored.csv")
df
# Out:
#       Unnamed: 0     Patient_ID  Age Gender   BMI  Heart_Rate  Systolic_BP  \
# 0              0  sdv-id-ZEIKHc   44      F  27.6         127          137
# 1              1  sdv-id-cXindf   46      F  26.7         107          161
# 2              2  sdv-id-OILsjH   68      F  25.4         109          145
# 3              3  sdv-id-LlLcvC   75      M  24.5         101          142
# 4              4  sdv-id-bfmNbx   59      O  22.3          70          138
# ...          ...            ...  ...    ...   ...         ...          ...
# 9995        9995  sdv-id-MReans   50      F  21.5         108          150
# 9996        9996  sdv-id-lHOdCy   67      O  29.4          68          136
# 9997        9997  sdv-id-TrokRn   23      M  23.4         112          110
# 9998        9998  sdv-id-cEWJQV   56      O  31.6         106          183
# 9999        9999  sdv-id-eEXKyz   76      F  32.8         115          182
#
# ...

# %%
df.drop(columns=["Risk_Level", "Risk_Score"], inplace=True)

# %%
df
# Out:
#       Unnamed: 0     Patient_ID  Age Gender   BMI  Heart_Rate  Systolic_BP  \
# 0              0  sdv-id-ZEIKHc   44      F  27.6         127          137
# 1              1  sdv-id-cXindf   46      F  26.7         107          161
# 2              2  sdv-id-OILsjH   68      F  25.4         109          145
# 3              3  sdv-id-LlLcvC   75      M  24.5         101          142
# 4              4  sdv-id-bfmNbx   59      O  22.3          70          138
# ...          ...            ...  ...    ...   ...         ...          ...
# 9995        9995  sdv-id-MReans   50      F  21.5         108          150
# 9996        9996  sdv-id-lHOdCy   67      O  29.4          68          136
# 9997        9997  sdv-id-TrokRn   23      M  23.4         112          110
# 9998        9998  sdv-id-cEWJQV   56      O  31.6         106          183
# 9999        9999  sdv-id-eEXKyz   76      F  32.8         115          182
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             10000 non-null  int64
#  1   Patient_ID             10000 non-null  object
#  2   Age                    10000 non-null  int64
#  3   Gender                 10000 non-null  object
#  4   BMI                    10000 non-null  float64
#  5   Heart_Rate             10000 non-null  int64
#  6   Systolic_BP            10000 non-null  int64
#  7   Diastolic_BP           10000 non-null  int64
#  8   O2_Saturation          10000 non-null  int64
#  9   Temp                   10000 non-null  float64
#  10  Respiratory_Rate       10000 non-null  int64
#  11  Pain_Score             10000 non-null  int64
#  12  GCS_Score              10000 non-null  int64
#  13  History_Diabetes       10000 non-null  int64
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0           Age           BMI    Heart_Rate   Systolic_BP  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    4999.50000     52.536400     26.569850     96.891700    133.329200
# std     2886.89568     21.256996      4.003828     22.768505     26.855188
# min        0.00000     19.000000     19.500000     54.000000     80.000000
# 25%     2499.75000     34.000000     23.300000     79.000000    112.000000
# 50%     4999.50000     51.000000     26.300000     95.000000    133.000000
# 75%     7499.25000     70.000000     29.600000    114.000000    155.000000
# max     9999.00000     94.000000     36.200000    150.000000    190.000000
#
#        Diastolic_BP  O2_Saturation          Temp  Respiratory_Rate  \
# count  10000.000000   10000.000000  10000.000000      10000.000000
# mean      84.055200      94.351000     37.255910         19.163600
# std       15.593565       3.566941      0.659324          4.449271
# ...

# %%
df.rename(columns={"Calculated_Risk_Score": "Risk_Score", "Calculated_Risk_Level": "Risk_Level"}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             10000 non-null  int64
#  1   Patient_ID             10000 non-null  object
#  2   Age                    10000 non-null  int64
#  3   Gender                 10000 non-null  object
#  4   BMI                    10000 non-null  float64
#  5   Heart_Rate             10000 non-null  int64
#  6   Systolic_BP            10000 non-null  int64
#  7   Diastolic_BP           10000 non-null  int64
#  8   O2_Saturation          10000 non-null  int64
#  9   Temp                   10000 non-null  float64
#  10  Respiratory_Rate       10000 non-null  int64
#  11  Pain_Score             10000 non-null  int64
#  12  GCS_Score              10000 non-null  int64
#  13  History_Diabetes       10000 non-null  int64
# ...

# %%
df.to_csv(r"D:\codes\Datasets\patients_data_scored.csv", index=False)
